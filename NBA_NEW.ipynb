# %%
import numpy as np
import pandas as pd
import seaborn as sns
import os

# %%
cd ~/Desktop/GA/NBA_Player_Prediction/
# Out:
# /Users/pwalesdi/Desktop/GA/NBA_Player_Prediction

# %%
nba_2019 = pd.read_csv('./test.txt', sep=",")

# %%
nba_2019.columns
# Out:
# Index(['Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'MP', 'PER', 'TS%', '3PAr',
#        'FTr', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%',
#        'Unnamed: 19', 'OWS', 'DWS', 'WS', 'WS/48', 'Unnamed: 24', 'OBPM',
#        'DBPM', 'BPM', 'VORP', 'player_name', 'player_id'],
#       dtype='object')

# %%
nba_2019[['player_name','player_id']] = nba_2019.Player.str.split("\\", expand=True)

# %%
nba_2019
# Out:
#       Rk                            Player Pos  Age   Tm   G    MP   PER  \
# 0      1            Álex Abrines\abrinal01  SG   25  OKC  31   588   6.3
# 1      2                Quincy Acy\acyqu01  PF   28  PHO  10   123   2.9
# 2      3            Jaylen Adams\adamsja01  PG   22  ATL  34   428   7.6
# 3      4            Steven Adams\adamsst01   C   25  OKC  80  2669  18.5
# 4      5             Bam Adebayo\adebaba01   C   21  MIA  82  1913  17.9
# 5      6                Deng Adel\adelde01  SF   21  CLE  19   194   2.7
# 6      7  DeVaughn Akoon-Purcell\akoonde01  SG   25  DEN   7    22   8.2
# 7      8       LaMarcus Aldridge\aldrila01   C   33  SAS  81  2687  22.9
# 8      9            Rawle Alkins\alkinra01  SG   21  CHI  10   120   8.1
# 9     10           Grayson Allen\allengr01  SG   23  UTA  38   416   7.5
# 10    11           Jarrett Allen\allenja01   C   20  BRK  80  2096  18.5
# 11    12            Kadeem Allen\allenka01  SG   26  NYK  19   416  16.2
# ...
