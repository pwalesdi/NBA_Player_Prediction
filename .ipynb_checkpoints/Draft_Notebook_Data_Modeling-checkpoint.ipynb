# %%
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

pd.set_option('display.max_rows', 2000)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %%
nba_data = pd.read_csv("./draft_picks_2006_2019.csv")

# %%
nba_data.loc[(nba_data['PLAYER_NAME'] == "Khris Middleton")]
# Out:
#          PLAYER_NAME Pos  Age   Tm   G    MP   PER    TS%   3PAr    FTr  ORB%  DRB%  TRB%  AST%  STL%  BLK%  TOV%  USG%  OWS  DWS   WS  WS/48  OBPM  DBPM  BPM  VORP  SEASON  PERSON_ID  DRAFT_YEAR+1  ROUND_NUMBER  ROUND_PICK  OVERALL_PICK DRAFT_TYPE     TEAM_ID TEAM_CITY TEAM_NAME TEAM_ABBREVIATION ORGANIZATION   ORGANIZATION_TYPE
# 905  Khris Middleton  SF   27  MIL  77  2393  16.5  0.558  0.413  0.225   2.3  16.5   9.8  20.1   1.6   0.2  12.1  25.1  2.5  3.6  6.1  0.123   0.7   0.1  0.8   1.7    2019     203114          2013             2           9            39      Draft  1610612765   Detroit   Pistons               DET    Texas A&M  College/University
# ...

# %%
nba_data.loc[(nba_data['PLAYER_NAME'] == "CJ McCollum")]
# Out:
#      PLAYER_NAME Pos  Age   Tm   G    MP   PER    TS%   3PAr    FTr  ORB%  DRB%  TRB%  AST%  STL%  BLK%  TOV%  USG%  OWS  DWS   WS  WS/48  OBPM  DBPM  BPM  VORP  SEASON  PERSON_ID  DRAFT_YEAR+1  ROUND_NUMBER  ROUND_PICK  OVERALL_PICK DRAFT_TYPE     TEAM_ID TEAM_CITY      TEAM_NAME TEAM_ABBREVIATION ORGANIZATION   ORGANIZATION_TYPE
# 538  CJ McCollum  SG   27  POR  70  2375  17.0  0.553  0.358  0.154   2.9   9.7   6.3  13.8   1.1   0.9   7.4  25.5  4.0  1.7  5.6  0.114   2.2  -1.9  0.3   1.3    2019     203468          2014             1          10            10      Draft  1610612757  Portland  Trail Blazers               POR       Lehigh  College/University
# ...

# %%
sorted(nba_data['Tm'].unique())
# Out:
# ['ATL',
#  'BOS',
#  'BRK',
#  'CHA',
#  'CHI',
#  'CHO',
#  'CLE',
#  'DAL',
#  'DEN',
#  'DET',
#  'GSW',
#  'HOU',
#  'IND',
#  'LAC',
#  'LAL',
#  'MEM',
#  'MIA',
#  'MIL',
#  'MIN',
#  'NJN',
#  'NOH',
#  'NOK',
#  'NOP',
#  'NYK',
#  'OKC',
#  'ORL',
#  'PHI',
#  'PHO',
#  'POR',
#  'SAC',
#  'SAS',
#  'SEA',
#  'TOR',
#  'TOT',
#  'UTA',
#  'WAS']

# %%
nba_data['TEAM_ABBREVIATION'].unique())
# Out:
# ['ATL',
#  'BKN',
#  'BOS',
#  'CHA',
#  'CHI',
#  'CLE',
#  'DAL',
#  'DEN',
#  'DET',
#  'GSW',
#  'HOU',
#  'IND',
#  'LAC',
#  'LAL',
#  'MEM',
#  'MIA',
#  'MIL',
#  'MIN',
#  'NJN',
#  'NOH',
#  'NOK',
#  'NOP',
#  'NYK',
#  'OKC',
#  'ORL',
#  'PHI',
#  'PHX',
#  'POR',
#  'SAC',
#  'SAS',
#  'SEA',
#  'TOR',
#  'UTA',
#  'WAS']

# %%
results.loc[results[results['predicted'] != results['actual']].index]

# %%
rookie_year = nba_data.loc[(nba_data['SEASON'] == nba_data['DRAFT_YEAR+1'])]
rookie_year['TEAM_ABBREVIATION']
# Out:
# 0       PHX
# 1       NYK
# 2       PHI
# 3       CHA
# 4       LAC
# 5       MIL
# 6       ATL
# 7       UTA
# 8       CHI
# 9       IND
# 10      GSW
# 11      MEM
# 12      DAL
# 13      ATL
# 14      PHI
# 15      BKN
# 16      DET
# 17      DEN
# 19      DEN
# 21      DEN
# 24      POR
# 25      BKN
# 26      HOU
# 27      MIN
# 28      MIL
# 29      IND
# 30      DAL
# 31      PHX
# 32      PHI
# 34      PHI
# 36      LAL
# 38      PHX
# 40      SAC
# 42      ORL
# 44      MIN
# 45      NYK
# 47      SAC
# 49      CHA
# 51      DET
# 53      DEN
# 55      MIA
# 56      CHI
# 58      ATL
# 60      OKC
# 62      BKN
# 64      TOR
# 66      UTA
# 68      BKN
# 70      LAL
# 72      UTA
# 75      SAC
# 77      BOS
# 79      CHI
# 83      PHI
# 85      NOP
# 89      ATL
# 91      UTA
# 94      NYK
# 96      HOU
# 98      PHI
# 100     IND
# 102     DEN
# 104     BOS
# 105     PHX
# 106     BOS
# 110     LAL
# 113     BOS
# 116     PHX
# 119     MIN
# 122     NOP
# 123     NOP
# ...

# %%
rookie_year.loc[rookie_year[rookie_year['TEAM_ABBREVIATION'] != rookie_year['Tm']].index]
# Out:
#                   PLAYER_NAME    Pos  Age   Tm   G    MP   PER    TS%   3PAr    FTr  ORB%  DRB%  TRB%  AST%  STL%  BLK%  TOV%  USG%  OWS  DWS   WS  WS/48  OBPM  DBPM   BPM  VORP  SEASON  PERSON_ID  DRAFT_YEAR+1  ROUND_NUMBER  ROUND_PICK  OVERALL_PICK DRAFT_TYPE     TEAM_ID      TEAM_CITY      TEAM_NAME TEAM_ABBREVIATION                    ORGANIZATION   ORGANIZATION_TYPE
# 0               Deandre Ayton      C   20  PHO  71  2183  20.5  0.608  0.005  0.217  11.1  26.1  18.5   9.6   1.3   2.6  11.7  21.2  4.1  1.7  5.8  0.128  -0.1   0.2   0.2   1.2    2019    1629028          2019             1           1             1      Draft  1610612756        Phoenix           Suns               PHX                         Arizona  College/University
# ...

# %%
nba_data.loc[(nba_data['SEASON'] == nba_data['DRAFT_YEAR+1'])]['Tm'] != nba_data.loc[(nba_data['SEASON'] == nba_data['DRAFT_YEAR+1'])]['TEAM_ABBREVIATION']
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
# 5       True
# 6       True
# 7       True
# 8       True
# 9       True
# 10      True
# 11      True
# 12      True
# 13      True
# 14      True
# 15      True
# 16      True
# 17      True
# 19      True
# 21      True
# 24      True
# 25      True
# 26      True
# 27      True
# 28      True
# 29      True
# 30      True
# 31      True
# 32      True
# 34      True
# 36      True
# 38      True
# 40      True
# 42      True
# 44      True
# 45      True
# 47      True
# 49      True
# 51      True
# 53      True
# 55      True
# 56      True
# 58      True
# 60      True
# 62      True
# 64      True
# 66      True
# 68      True
# 70      True
# 72      True
# 75      True
# 77      True
# 79      True
# 83      True
# 85      True
# 89      True
# 91      True
# 94      True
# 96      True
# 98      True
# 100     True
# 102     True
# 104     True
# 105     True
# 106     True
# 110     True
# ...

# %%
nba_data.loc[
nba_data.loc[(nba_data['SEASON'] == nba_data['DRAFT_YEAR+1'])]['Tm'] != 
nba_data.loc[(nba_data['SEASON'] == nba_data['DRAFT_YEAR+1'])]['TEAM_ABBREVIATION'].index]
# Out:
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# <ipython-input-53-ddd332971099> in <module>
#       1 nba_data.loc[
#       2 nba_data.loc[(nba_data['SEASON'] == nba_data['DRAFT_YEAR+1'])]['Tm'] !=
# ----> 3 nba_data.loc[(nba_data['SEASON'] == nba_data['DRAFT_YEAR+1'])]['TEAM_ABBREVIATION'].index]
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1498
#    1499             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1500             return self._getitem_axis(maybe_callable, axis=axis)
#    1501
#    1502     def _is_scalar_access(self, key):
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1867             return self._get_slice_axis(key, axis=axis)
#    1868         elif com.is_bool_indexer(key):
# ...

# %%
yo = nba_data.loc[
    (nba_data['MP'] >= 1500) & 
    (nba_data['TS%'] >= 0.575) &
    (nba_data['VORP'] >= 3.5)].sort_values(by=['PER', 'SEASON'], ascending=False)

# %%
sns.set_style("ticks")
plt.figure(figsize=(15,10))
sns.scatterplot(x='PER', y='TS%', data=yo, hue='PLAYER_NAME', size='OWS', legend='brief', sizes=(25, 250))
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.);
